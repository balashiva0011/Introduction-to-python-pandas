# %% [markdown]
# <a href="https://colab.research.google.com/github/balashiva0011/Introduction-to-python-pandas/blob/main/case_study_bike_sales_europe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Creating a project on bike sales in Europe can be an interesting and insightful endeavor. The project could involve analyzing Revenue data to uncover trends, identify key factors affecting Revenue, and make data-driven recommendations for stakeholders. Here’s a comprehensive description for such a project:
# > Add blockquote

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Bike Sales in Europe.csv')

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26-11-2013   26  November  2013            19     Youth (<25)
# 1  26-11-2015   26  November  2015            19     Youth (<25)
# 2  23-03-2014   23     March  2014            49  Adults (35-64)
# 3  23-03-2016   23     March  2016            49  Adults (35-64)
# 4  15-05-2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%M')
df
# Out:
#            Date  Day      Month       Year  Customer_Age  \
# 0    26-11-2013   26   November 2013-01-01            19
# 1    26-11-2015   26   November 2015-01-01            19
# 2    23-03-2014   23      March 2014-01-01            49
# 3    23-03-2016   23      March 2016-01-01            49
# 4    15-05-2014   15        May 2014-01-01            47
# ..          ...  ...        ...        ...           ...
# 294  13-03-2014   13      March 2014-01-01            30
# 295  13-03-2016   13      March 2016-01-01            30
# 296  14-04-2014   14      April 2014-01-01            30
# 297  14-04-2016   14      April 2016-01-01            30
# 298  17-09-2013   17  September 2013-01-01            52
#
#                 Age_Group Customer_Gender        Country             State  \
# 0             Youth (<25)               M         Canada  British Columbia
# 1             Youth (<25)               M         Canada  British Columbia
# ...

# %%
print(df.dtypes)
# Out:
# Date                        object
# Day                          int64
# Month                       object
# Year                datetime64[ns]
# Customer_Age                 int64
# Age_Group                   object
# Customer_Gender             object
# Country                     object
# State                       object
# Product_Category            object
# Sub_Category                object
# Product                     object
# Order_Quantity               int64
# Unit_Cost                    int64
# Unit_Price                   int64
# Profit                       int64
# Cost                         int64
# Revenue                      int64
# dtype: object

# %%
df.isnull()
# Out:
#       Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0    False  False  False  False         False      False            False
# 1    False  False  False  False         False      False            False
# 2    False  False  False  False         False      False            False
# 3    False  False  False  False         False      False            False
# 4    False  False  False  False         False      False            False
# ..     ...    ...    ...    ...           ...        ...              ...
# 294  False  False  False  False         False      False            False
# 295  False  False  False  False         False      False            False
# 296  False  False  False  False         False      False            False
# 297  False  False  False  False         False      False            False
# 298  False  False  False  False         False      False            False
#
#      Country  State  Product_Category  Sub_Category  Product  Order_Quantity  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
df.dropna()
# Out:
#            Date  Day      Month       Year  Customer_Age  \
# 0    26-11-2013   26   November 2013-01-01            19
# 1    26-11-2015   26   November 2015-01-01            19
# 2    23-03-2014   23      March 2014-01-01            49
# 3    23-03-2016   23      March 2016-01-01            49
# 4    15-05-2014   15        May 2014-01-01            47
# ..          ...  ...        ...        ...           ...
# 294  13-03-2014   13      March 2014-01-01            30
# 295  13-03-2016   13      March 2016-01-01            30
# 296  14-04-2014   14      April 2014-01-01            30
# 297  14-04-2016   14      April 2016-01-01            30
# 298  17-09-2013   17  September 2013-01-01            52
#
#                 Age_Group Customer_Gender        Country             State  \
# 0             Youth (<25)               M         Canada  British Columbia
# 1             Youth (<25)               M         Canada  British Columbia
# ...

# %%
df_year = df.groupby('Date')['Age_Group'].sum()

# %%
df_year
# Out:
# Date
# 01-01-2014                                   Youth (<25)
# 01-01-2016                                   Youth (<25)
# 01-03-2014                                   Youth (<25)
# 01-03-2016                                   Youth (<25)
# 02-01-2014            Adults (35-64)Young Adults (25-34)
#                                  ...
# 31-07-2014                                   Youth (<25)
# 31-07-2015                          Young Adults (25-34)
# 31-07-2016                                   Youth (<25)
# 31-12-2013    Youth (<25)Youth (<25)Young Adults (25-34)
# 31-12-2015    Youth (<25)Youth (<25)Young Adults (25-34)
# Name: Age_Group, Length: 250, dtype: object

# %%
df = df[df['Country'] == 'Canada']

# %%
df
# Out:
#            Date  Day      Month       Year  Customer_Age  \
# 0    26-11-2013   26   November 2013-01-01            19
# 1    26-11-2015   26   November 2015-01-01            19
# 14   02-08-2013    2     August 2013-01-01            29
# 15   02-08-2015    2     August 2015-01-01            29
# 16   02-09-2013    2  September 2013-01-01            29
# 17   02-09-2015    2  September 2015-01-01            29
# 18   22-01-2014   22    January 2014-01-01            29
# 19   22-01-2016   22    January 2016-01-01            29
# 20   17-05-2014   17        May 2014-01-01            29
# 21   17-05-2016   17        May 2016-01-01            29
# 24   25-08-2013   25     August 2013-01-01            49
# 25   25-08-2015   25     August 2015-01-01            49
# 26   26-12-2013   26   December 2013-01-01            49
# 27   26-12-2015   26   December 2015-01-01            49
# 28   02-01-2014    2    January 2014-01-01            48
# ...

# %%
df = df.rename(columns={'State	': 'States', 'Sub_Category': 'Sub_Categorys'})

print(df)
# Out:
#            Date  Day      Month       Year  Customer_Age  \
# 0    26-11-2013   26   November 2013-01-01            19
# 1    26-11-2015   26   November 2015-01-01            19
# 14   02-08-2013    2     August 2013-01-01            29
# 15   02-08-2015    2     August 2015-01-01            29
# 16   02-09-2013    2  September 2013-01-01            29
# 17   02-09-2015    2  September 2015-01-01            29
# 18   22-01-2014   22    January 2014-01-01            29
# 19   22-01-2016   22    January 2016-01-01            29
# 20   17-05-2014   17        May 2014-01-01            29
# 21   17-05-2016   17        May 2016-01-01            29
# 24   25-08-2013   25     August 2013-01-01            49
# 25   25-08-2015   25     August 2015-01-01            49
# 26   26-12-2013   26   December 2013-01-01            49
# 27   26-12-2015   26   December 2015-01-01            49
# 28   02-01-2014    2    January 2014-01-01            48
# ...

# %%
rows = df.iloc[[0, 1],[0,1]]
print(rows)
# Out:
#          Date  Day
# 0  26-11-2013   26
# 1  26-11-2015   26

# %%
rows = df.iloc[0]
print(rows)
# Out:
# Date                         26-11-2013
# Day                                  26
# Month                          November
# Year                2013-01-01 00:00:00
# Customer_Age                         19
# Age_Group                   Youth (<25)
# Customer_Gender                       M
# Country                          Canada
# State                  British Columbia
# Product_Category            Accessories
# Sub_Categorys                Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                        8
# Unit_Cost                            45
# Unit_Price                          120
# Profit                              590
# Cost                                360
# Revenue                             950
# Name: 0, dtype: object

# %%
columns = df.iloc[:, 0:2]
print(columns)
# Out:
#            Date  Day
# 0    26-11-2013   26
# 1    26-11-2015   26
# 14   02-08-2013    2
# 15   02-08-2015    2
# 16   02-09-2013    2
# 17   02-09-2015    2
# 18   22-01-2014   22
# 19   22-01-2016   22
# 20   17-05-2014   17
# 21   17-05-2016   17
# 24   25-08-2013   25
# 25   25-08-2015   25
# 26   26-12-2013   26
# 27   26-12-2015   26
# 28   02-01-2014    2
# 29   02-01-2016    2
# 30   13-03-2014   13
# 31   13-03-2016   13
# 32   23-05-2014   23
# 33   23-05-2016   23
# 36   11-11-2013   11
# 37   11-11-2015   11
# 44   27-08-2013   27
# 45   27-08-2015   27
# 46   17-11-2013   17
# 47   17-11-2015   17
# 64   26-11-2013   26
# 65   26-11-2015   26
# 66   03-08-2013    3
# 67   03-08-2015    3
# 68   19-06-2014   19
# 69   19-06-2016   19
# 102  29-09-2013   29
# 103  29-09-2015   29
# 104  16-05-2014   16
# 105  16-05-2016   16
# 142  18-08-2013   18
# 143  18-08-2015   18
# 162  07-09-2013    7
# 163  07-09-2015    7
# 212  11-06-2014   11
# 213  11-06-2016   11
# ...

# %%
df = df.drop("Unit_Cost",axis=1)
print(df)
# Out:
#            Date  Day      Month       Year  Customer_Age  \
# 0    26-11-2013   26   November 2013-01-01            19
# 1    26-11-2015   26   November 2015-01-01            19
# 14   02-08-2013    2     August 2013-01-01            29
# 15   02-08-2015    2     August 2015-01-01            29
# 16   02-09-2013    2  September 2013-01-01            29
# 17   02-09-2015    2  September 2015-01-01            29
# 18   22-01-2014   22    January 2014-01-01            29
# 19   22-01-2016   22    January 2016-01-01            29
# 20   17-05-2014   17        May 2014-01-01            29
# 21   17-05-2016   17        May 2016-01-01            29
# 24   25-08-2013   25     August 2013-01-01            49
# 25   25-08-2015   25     August 2015-01-01            49
# 26   26-12-2013   26   December 2013-01-01            49
# 27   26-12-2015   26   December 2015-01-01            49
# 28   02-01-2014    2    January 2014-01-01            48
# ...

# %%
result = df['Revenue'].agg(['sum','mean'])
print(result)
# Out:
# sum     57276.000000
# mean     1060.666667
# Name: Revenue, dtype: float64

# %%
result = df['Revenue'].agg(['sum','mean','max','min'])
print(result)
# Out:
# sum     57276.000000
# mean     1060.666667
# max      3564.000000
# min       119.000000
# Name: Revenue, dtype: float64

# %%
result = df.agg({
    'Revenue': ['mean', 'sum'],
    'Profit': ['max', 'min']})
print(result)
# Out:
#            Revenue  Profit
# mean   1060.666667     NaN
# sum   57276.000000     NaN
# max            NaN  2214.0
# min            NaN    74.0

# %%
grouped_agg = df.groupby('Sub_Categorys').agg({
    'Revenue': ['mean', 'sum', 'max', 'min']})
print(grouped_agg)
# Out:
#                    Revenue
#                       mean    sum   max  min
# Sub_Categorys
# Bike Racks     1060.666667  57276  3564  119

# %%
def range_func(x):
    return x.max() - x.min()

# Apply custom function to grouped data
custom_agg = df.groupby('Sub_Categorys').agg({
    'Revenue': range_func,
    'Profit': 'mean'
})

print(custom_agg)
# Out:
#                Revenue  Profit
# Sub_Categorys
# Bike Racks        3445   659.0

# %%
import matplotlib.pyplot as plt

# %%
sales_trends = df.groupby('Sub_Categorys')['Revenue'].sum()

# Plot
plt.figure(figsize=(10, 6))
plt.plot(sales_trends.index, sales_trends.values, marker='o')
plt.title('Bike Sales Trends Over Time')
plt.xlabel('Sub_Categorys')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['Revenue'], labels=df['Product'], autopct='%1.1f%%', startangle=140)
plt.title('Market Share by Customer Segment')
plt.show()

# %%
sales_by_type = df.groupby('Sub_Categorys')['Revenue'].sum()

# Plot
plt.figure(figsize=(10, 6))
sales_by_type.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Bike Type')
plt.xlabel('Sub_Categorys')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.boxplot(column='Revenue', by='Sub_Categorys', grid=False)
plt.title('Sales Distribution by Country')
plt.suptitle('')  # Remove the default title to avoid overlap
plt.xlabel('Sub_Categorys')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
